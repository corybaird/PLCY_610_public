# %% [markdown]
# # TA session: 09_17_2020

# %% [markdown]
# ## A.1 Install libraries

# %%
#Step 1: Must install
install.packages("dplyr")

# %%
#Step 2: After step 1 you must run library function
library(dplyr)

# %% [markdown]
# ## A.2 Import data

# %%
url = 'https://raw.githubusercontent.com/corybaird/PLCY_610_public/master/Discussion_sections/Disc2_PS1/vote.csv'
df = read.csv(url)

# %%
# Show data
df %>% head(3)
# Out:
#   state vote income education age sex
# 1 AR    1     9     2         73  0
# 2 AR    1    11     2         24  0
# 3 AR    0    12     2         24  1

# %% [markdown]
# # Z-score

# %% [markdown]
# ## Z.1 Calculate Z-score using dplyr--mutate function

# %%
df %>% 
  select(age) %>% 
  mutate(
  age_mean = mean(age),
  age_std = sd(age),
  age_z_score = (age-mean(age))/sd(age), # age-mean(age)/sd(age)
  ) %>% head(10)
# Out:
#    age age_mean age_std  age_z_score
# 1  73  49.27896 17.59183  1.3484123
# 2  24  49.27896 17.59183 -1.4369718
# 3  24  49.27896 17.59183 -1.4369718
# 4  40  49.27896 17.59183 -0.5274586
# 5  85  49.27896 17.59183  2.0305472
# 6  78  49.27896 17.59183  1.6326352
# 7  31  49.27896 17.59183 -1.0390598
# 8  75  49.27896 17.59183  1.4621015
# 9  54  49.27896 17.59183  0.2683654
# 10 78  49.27896 17.59183  1.6326352

# %% [markdown]
# ## Z.2 Save new dataframe

# %%
df_zscores = df %>% 
  select(age) %>% 
  mutate(
  age_mean = mean(age),
  age_std = sd(age),
  age_z_score = (age-mean(age))/sd(age), # age-mean(age)/sd(age)
  )

# %% [markdown]
# ## Z.3 Plot zscores vs original data

# %%
#Create histograms side by side
par(mfrow=c(1,2))

#Hist 1
hist(df_zscores$age_z_score)

#Hist 2
hist(df_zscores$age,
     #ylim = c(0,400),
     #xlim = c(0,100)
     )
# Out:
# Plot with title “Histogram of df_zscores$age”

# %% [markdown]
# # Filter outliers
# - This is just for reference it does not need to be use in PS1

# %% [markdown]
# ## F.1 Find outlier data: DPLYR--Filter

# %%
df %>% 
  filter(
    age>100
  )
# Out:
#   state vote income education age sex
# 1 SC    1    8      1         120 1

# %% [markdown]
# ## F.2 Save new data frame WITHOUT outlier
# - Note: the filter is inverse of the code above

# %%
df_no_outlier = df %>% 
  filter(
    age<100
  )

# %%
hist(df_no_outlier$age)
# Out:
# Plot with title “Histogram of df_no_outlier$age”

# %% [markdown]
# # IQR

# %% [markdown]
# ## I.1 IQR function

# %%
IQR(df$age)
# Out:
# [1] 26

# %% [markdown]
# ## I.2 Find quartile data only

# %%
summary(df$age)[2] #Grab second column
summary(df$age)[5] #Grab fifth column
# Out:
# 1st Qu.
#      36
# 3rd Qu.
#      62

# %% [markdown]
# # Unique observations
#
# - Shows unique observations

# %%
unique(df$vote)
# Out:
# [1] 1 0

# %%
unique(df$income)
# Out:
#  [1]  9 11 12 16 10 14 17  8 15 13  5  6  7  4
