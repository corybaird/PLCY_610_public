# %% [markdown]
# # Problem set 5
#
# - Below are the functions necessary to complete problem set 5
# - We will use an internal data set that is available in r-studio

# %% [markdown]
# ## A.1 Import receipts data

# %%
#Imports internal data set
datasets(mtcars)
# Out:
# Error in datasets(mtcars): could not find function "datasets"
# Traceback:

# %% [markdown]
# ## A.2 Import packages

# %%
library(dplyr) #Data manipulation
library(ggplot2) #Plotting
